# %% [markdown]
# # Picture resizer for Insta
# This notebook can be used to circumscribe any picture in a square so that the full picture is visible on Insta.

# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
if "../" not in sys.path:
    sys.path.insert(0, "../")
from scripts.picture_edition import clean_pictures, square_picture, save_square_pictures

import cv2 as cv
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
img_path = "../data/insta_example/"

# %% [markdown]
# Reset rotation of pictures in case they were rotated

# %%
clean_pictures(from_dir = img_path, to_dir = img_path, rotate = True, rename = False)

# %% [markdown]
# Square the pictures and save them in a folder

# %%
save_square_pictures(img_path)

# %% [markdown]
# Check a result

# %%
from IPython.display import Image
img_name = os.listdir(img_path + "squared/")[-1]
Image(filename=img_path + "squared/" + img_name)
